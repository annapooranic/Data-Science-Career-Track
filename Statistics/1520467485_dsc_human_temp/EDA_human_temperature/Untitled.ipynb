# %%
import pandas as pd

df = pd.read_csv('data/human_body_temperature.csv')

# %%
df
# Out:
#      temperature gender  heart_rate
# 0           99.3      F        68.0
# 1           98.4      F        81.0
# 2           97.8      M        73.0
# 3           99.2      F        66.0
# 4           98.0      F        73.0
# 5           99.2      M        83.0
# 6           98.0      M        71.0
# 7           98.8      M        78.0
# 8           98.4      F        84.0
# 9           98.6      F        86.0
# 10          98.8      F        89.0
# 11          96.7      F        62.0
# 12          98.2      M        72.0
# 13          98.7      F        79.0
# 14          97.8      F        77.0
# 15          98.8      F        83.0
# 16          98.3      F        79.0
# 17          98.2      M        64.0
# 18          97.2      F        68.0
# 19          99.4      M        70.0
# 20          98.3      F        78.0
# 21          98.2      M        71.0
# 22          98.6      M        70.0
# 23          98.4      M        68.0
# 24          97.8      M        65.0
# 25          98.0      F        87.0
# 26          97.8      F        62.0
# 27          98.2      F        69.0
# 28          98.4      F        73.0
# 29          98.1      M        67.0
# ..           ...    ...         ...
# 100         99.0      M        81.0
# 101         98.5      M        68.0
# 102         98.0      F        78.0
# 103         99.4      F        77.0
# 104         97.6      M        69.0
# 105         96.7      M        71.0
# 106         97.0      M        80.0
# 107         98.6      M        66.0
# 108         98.7      F        72.0
# 109         97.3      M        69.0
# 110         98.8      F        69.0
# 111         98.0      F        89.0
# 112         98.2      F        64.0
# 113         99.1      F        74.0
# 114         99.0      M        79.0
# 115         98.0      M        64.0
# 116        100.8      F        77.0
# 117         97.8      F        71.0
# 118         98.7      M        78.0
# 119         98.4      F        74.0
# 120         97.7      F        84.0
# 121         97.9      F        68.0
# 122         99.0      F        81.0
# 123         97.2      F        66.0
# 124         97.5      M        75.0
# 125         96.3      M        70.0
# 126         97.7      M        77.0
# 127         98.2      F        73.0
# 128         97.9      M        72.0
# 129         98.7      F        59.0
#
# [130 rows x 3 columns]

# %%
df.temperature.mean()
df.temperature.median()
# Out:
# 98.3

# %%
import seaborn as sns
sns.distplot(df.temperature)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ff54f575f377> in <module>()
#       1 import seaborn as sns
#       2 sns.distplot(df.temperature)
# ----> 3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.temperature.mean()
# Out:
# 98.24923076923078

# %%
df.temperature.median()
# Out:
# 98.3

# %%
df.temperature.mode()
# Out:
# 0    98.0
# dtype: float64

# %%
df.temperature.describe()
# Out:
# count    130.000000
# mean      98.249231
# std        0.733183
# min       96.300000
# 25%       97.800000
# 50%       98.300000
# 75%       98.700000
# max      100.800000
# Name: temperature, dtype: float64

# %%
import statsmodels.api as sm
import numpy as np
mean = np.mean(df['temperature'])
sd = np.std(df['temperature'])
z = (df['temperature'] - mean) / sd
sm.qqplot(z, line='45')

# %%
import scipy.stats as stats
stats.mstats.normaltest(df['temperature'])
# Out:
# NormaltestResult(statistic=2.703801433319203, pvalue=0.2587479863488254)
